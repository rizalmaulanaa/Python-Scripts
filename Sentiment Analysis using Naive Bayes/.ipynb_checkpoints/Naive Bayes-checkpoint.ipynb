# %%
import numpy as np
import pandas as pd
import re

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()
stop = open('stopword tala.txt','r')
stoplist = stop.read().split('\n')
stop.close()
path = '/Users/Rizal Maulana/Downloads/semester 7/TextMin/'

# %% [markdown]
# # Read Data

# %%
data = pd.read_excel(path+'Dataset Kelompok 4.xlsx')
korpus = data['Komentar']
label = data['Hasil akhir']
korpus
# Out:
# 0     Hebat and keren MRT ,kami menunggu fase beriku...
# 1     Bangga rasanya punya mrt. Meskipun belum perna...
# 2     Wah keren sekali❤️ terima kasih sudah mewujudk...
# 3     Keren.....Semoga kota2 lain di Indonesia seger...
# 4                     Hore.. akhirnya Jakarta punya MRT
# 5          Semangat untuk perubahan yang luar biasa! 👍👍
# 6     Mantap betul, maju terus indonesia & terus ber...
# 7                      MRT keren banget, Indonesia maju
# 8                   Lebih enak daripada Transjakarta ya
# 9     Mantap, smoga suatu hari nanti mrt bisa sambun...
# 10    Alhamdulillah sudah mencoba MRT Jakarta .. bag...
# 11    Bagus, bersih dan pelayanan nya memuaskan semo...
# 12    Keren MRTJ yang membuatku berubah ke transport...
# 13    bersih dan nyaman...fasilitasnya bagus dan pet...
# 14    Nyaman, tepat, cepat, kualitas stasiun dan ker...
# 15    Min, eskalator di Istora Mandiri yg exit BEI k...
# 16    Harusnya genset berfungsi untuk jalur MRT seti...
# 17    Hanya untuk evakuasi tp tidak untuk kelangsung...
# 18                Bahaya ini kalau MRT tidak ada genset
# 19    Fasilitas mrt masih kurang tempat duduk di sel...
# 20    Petunjuk lebih banyak.... Ada eskalator turun ...
# 21    Pls diperhatikan untuk gate di dukuh atas. Kar...
# 22    Halo, MRT Jakarta. Musholla di Stasiun MRT Ben...
# 23    Min masukan 1. akses untuk disabilitas masih k...
# 24    coba, @mrtjakarta y kali minum mineral water d...
# 25    Tolong sistem ticketingnya dibenahi. Masa Buat...
# 26    Kurang ada unsur visual yg melarang. Tambahkan...
# 27    Demi menjaga kebersihan di stasiun mrt tolong ...
# 28    Entah kenapa ya min, pelayanan loket MRT dan C...
# 29    Tiket Multi Tripnya kapan dong ? Lama nih. Peg...
# Name: Komentar, dtype: object

# %% [markdown]
# # K-Fold

# %%
k_fold = []
k = 3
flag = [0,15]

for i in range(0,5):
    temp = []
    for j in flag:
        temp += list(label[j:j+k].index)
    k_fold.append(temp)
    flag = [h+k for h in flag]
    
k_fold
# Out:
# [[0, 1, 2, 15, 16, 17],
#  [3, 4, 5, 18, 19, 20],
#  [6, 7, 8, 21, 22, 23],
#  [9, 10, 11, 24, 25, 26],
#  [12, 13, 14, 27, 28, 29]]

# %% [markdown]
# # Text Preprocessing

# %%
full_term = []
for doc in korpus:
    token = re.findall(r'\b[A-Za-z]{1,}',doc)
    term = []
    for word in token:
        if word not in stoplist:
            term.append(stemmer.stem(word.lower()))
    full_term.append(term)

full_term
# Out:
# [['hebat', 'and', 'keren', 'mrt', 'tunggu', 'fase'],
#  ['bangga', 'mrt', 'meski', 'full'],
#  ['wah',
#   'keren',
#   'terima',
#   'kasih',
#   'wujud',
#   'harap',
#   'angan',
#   'warga',
#   'jakarta',
#   'milik',
#   'fasilitas',
#   'moda',
#   'transportasi',
#   'modern'],
#  ['keren', 'moga', 'kota', 'indonesia', 'milik', 'mrt'],
#  ['hore', 'jakarta', 'mrt'],
#  ['semangat', 'ubah'],
#  ['mantap', 'maju', 'indonesia', 'kembang'],
#  ['mrt', 'keren', 'banget', 'indonesia', 'maju'],
#  ['lebih', 'enak', 'transjakarta', 'ya'],
#  ['mantap', 'smoga', 'mrt', 'sambung', 'jonggol'],
#  ['alhamdulillah',
#   'coba',
#   'mrt',
#   'jakarta',
#   'bagus',
#   'lancar',
#   'cepat',
#   'nyaman',
#   'bersih',
#   'modern',
#   'selamat',
#   'moga',
#   'sukses',
#   'awat'],
#  ['bagus',
#   'bersih',
#   'layan',
#   'nya',
#   'muas',
#   'moga',
#   'hubung',
#   'kerjasama',
#   'nya',
#   'tingkat'],
#  ['keren',
#   'mrtj',
#   'buat',
#   'ubah',
#   'transportasi',
#   'hari',
#   'lama',
#   'pergi',
#   'pulang',
#   'kantor',
#   'tenggelam',
#   'macet',
#   'nikmat',
#   'jakarta',
#   'mrt',
#   'yuknaikmrt'],
#  ['bersih',
#   'nyaman',
#   'fasilitas',
#   'bagus',
#   'tugas',
#   'cekat',
#   'bantu',
#   'masarakat'],
#  ['nyaman', 'cepat', 'kualitas', 'stasiun', 'kereta', 'bagus'],
#  ['min',
#   'eskalator',
#   'istora',
#   'mandiri',
#   'yg',
#   'exit',
#   'bei',
#   'kapaaan',
#   'sumpah',
#   'lelah',
#   'banget',
#   'pagi'],
#  ['harus',
#   'genset',
#   'fungsi',
#   'jalur',
#   'mrt',
#   'kereta',
#   'henti',
#   'stasiun',
#   'evakuasi',
#   'dlm',
#   'tunnel',
#   'jalan',
#   'lintas',
#   'layang',
#   'bahaya',
#   'kereta',
#   'henti',
#   'stasiun'],
#  ['hanya',
#   'evakuasi',
#   'tp',
#   'langsung',
#   'operasi',
#   'bahaya',
#   'evakuasi',
#   'jalur',
#   'lorong',
#   'mrt',
#   'rencana',
#   'prosedur',
#   'darurat',
#   'yg',
#   'pada'],
#  ['bahaya', 'mrt', 'genset'],
#  ['fasilitas', 'mrt', 'duduk', 'stasiun', 'mrt'],
#  ['tunjuk',
#   'ada',
#   'eskalator',
#   'turun',
#   'nya',
#   'lansia',
#   'susah',
#   'jalan',
#   'antri',
#   'lift',
#   'nya'],
#  ['pls',
#   'perhati',
#   'gate',
#   'dukuh',
#   'kartu',
#   'sy',
#   'tgl',
#   'gak',
#   'hasil',
#   'debet',
#   'kartu',
#   'gak',
#   'bayar',
#   'loket',
#   'padahal',
#   'kalo',
#   'gak',
#   'hasil',
#   'debet',
#   'pintu',
#   'gate',
#   'gak',
#   'buka',
#   'ini',
#   'udh',
#   'jadi',
#   'kaya',
#   'gin',
#   'tolong',
#   'perhati',
#   'thx'],
#  ['halo',
#   'mrt',
#   'jakarta',
#   'musholla',
#   'stasiun',
#   'mrt',
#   'bendung',
#   'hilir',
#   'shaf',
#   'solat',
#   'gak',
#   'kasi',
#   'orang',
#   'solat',
#   'tunda',
#   'gak',
#   'shaf',
#   'solat',
#   'wudhu',
#   'keran',
#   'mohon',
#   'besar',
#   'ya'],
#  ['min',
#   'masuk',
#   'akses',
#   'disabilitas',
#   'informasi',
#   'mana',
#   'arah',
#   'lift',
#   'tidak',
#   'peta',
#   'lengkap',
#   'mrt',
#   'ketika',
#   'pintu',
#   'tutup',
#   'tanda',
#   'tanda',
#   'bunyi',
#   'orang',
#   'aware'],
#  ['coba',
#   'mrtjakarta',
#   'y',
#   'kali',
#   'minum',
#   'mineral',
#   'water',
#   'stasiun',
#   'larang',
#   'n',
#   'top',
#   'out',
#   'dl',
#   'coba',
#   'tinjau',
#   'ulang',
#   'kasihan',
#   'anak',
#   'kadang',
#   'ngerengek',
#   'minum',
#   'asa',
#   'dubai',
#   'aja',
#   'gk',
#   'lebay',
#   'gn',
#   'deh'],
#  ['tolong',
#   'sistem',
#   'ticketingnya',
#   'benah',
#   'masa',
#   'buat',
#   'refund',
#   'tiket',
#   'single',
#   'trip',
#   'aja',
#   'butuh',
#   'jam',
#   'ngantri'],
#  ['kurang',
#   'unsur',
#   'visual',
#   'yg',
#   'larang',
#   'tambah',
#   'simbol',
#   'larang',
#   'forbidden'],
#  ['demi',
#   'jaga',
#   'bersih',
#   'stasiun',
#   'mrt',
#   'tolong',
#   'banyakin',
#   'sampah',
#   'udh',
#   'gede',
#   'sampah',
#   'gak',
#   'pintu',
#   'masuk',
#   'stasiun',
#   'aja',
#   'gk',
#   'tmpt',
#   'sampah'],
#  ['entah',
#   'ya',
#   'min',
#   'layan',
#   'loket',
#   'mrt',
#   'commuter',
#   'line',
#   'beda',
#   'segi',
#   'cepat',
#   'loket',
#   'mrt',
#   'butuh',
#   'transaksi',
#   'loket',
#   'commuter',
#   'kalau',
#   'sih',
#   'ngeliat',
#   'sdmnya',
#   'ya',
#   'sop',
#   'nya',
#   'ribet',
#   'sistem',
#   'komputer',
#   'soft',
#   'hardwarenya',
#   'efisien'],
#  ['tiket',
#   'multi',
#   'trip',
#   'lama',
#   'nih',
#   'gel',
#   'hrs',
#   'isi',
#   'ulang',
#   'kali',
#   'jalan',
#   'mesin',
#   'kadang',
#   'antri',
#   'loket',
#   'cepat',
#   'baca',
#   'mesin',
#   'cepat',
#   'pake',
#   'kartu',
#   'mrt',
#   'drpd',
#   'kartu',
#   'bank',
#   'kartu',
#   'bank',
#   'kadang',
#   'baca',
#   'butuh',
#   'wkt',
#   'nunggu',
#   'multi',
#   'trip',
#   'cardnya',
#   'nih']]

# %% [markdown]
# # Pembobotan Term

# %%
def pembobotan(doc_term,doc_test):
    term = np.unique(sum(doc_term,[]))
    columns = [i for i in range(len(doc_term))]
    dtm = pd.DataFrame(0,index=term,columns=columns)

    for i,doc in enumerate(doc_term):
        for term in doc:
            dtm.loc[term,i] += 1
    
    term_test = np.unique(sum(doc_test,[]))
    columns = [i for i in range(len(doc_test))]
    dtm_test = pd.DataFrame(0,index=dtm.index,columns=columns)
    
    for i,doc in enumerate(doc_test):
        for term in doc:
            if term in dtm.index:
                dtm_test.loc[term,i] += 1
            
    return dtm, dtm_test

# %% [markdown]
# # Naive Bayes

# %%
class Naive_Bayes(object):
    
    def train(self,df_train,y_train):
        self.prior = {j:(i/len(y_train)) for i,j in zip(y_train.value_counts(),y_train.value_counts().index)}
        self.cp = pd.DataFrame(0,df_train.index,columns=self.prior)
        y_group = y_train.groupby(y_train)
        
        for i in self.prior.keys():
            for j in df_train.index:
                atas = df_train.loc[j,y_group.get_group(i).index].sum()+1
                bawah = df_train[y_group.get_group(i).index].sum().sum()+len(df_train.index)
                self.cp.loc[j,i] = atas/bawah
        
        print('Training data finish')

    def test(self,df_test):
        hasil = []
        for i in df_test.columns:
            temp = {}
            for j in self.prior.keys():
                temp[j] = np.prod(self.cp[df_test[i] > 0][j])*self.prior[j]

            hasil.append(max(temp,key=temp.get))
        
        return hasil
    
    def akurasi(self,y_true,y_predict):
        total = 0
        for i,j in zip(y_true,y_predict):
            if i == j:
                total += 1
                
        return total/len(y_true)

# %% [markdown]
# # Evaluasi

# %%
akurasi = []
for k,i in enumerate(k_fold):
    print('K-Fold ke {}'.format(k+1))
    y_train = label[~label.index.isin(i)]
    y_test = label[i]
    term_train = [full_term[j] for j in range(len(full_term)) if j not in i]
    term_test = [full_term[j] for j in i]

    dtm_train,dtm_test = pembobotan(term_train,term_test)
    dtm_train.columns = y_train.index
    dtm_test.columns = y_test.index

    nb = Naive_Bayes()
    nb.train(dtm_train,y_train)
    y_predict = nb.test(dtm_test)
    print('Kelas asli : {}'.format(list(y_test)))
    print('Kelas prediksi: {}'.format(y_predict))
    temp_akurasi = nb.akurasi(y_test,y_predict)
    print('Akurasi : {}\n'.format(temp_akurasi))
    akurasi.append(temp_akurasi)

print('Nilai rata-rata akurasi {}'.format(np.mean(akurasi)))
# Out:
# K-Fold ke 1
# Training data finish
# Kelas asli : ['Positif', 'Positif', 'Positif', 'Negatif', 'Negatif', 'Negatif']
# Kelas prediksi: ['Positif', 'Negatif', 'Positif', 'Negatif', 'Negatif', 'Negatif']
# Akurasi : 0.8333333333333334
#
# K-Fold ke 2
# Training data finish
# Kelas asli : ['Positif', 'Positif', 'Positif', 'Negatif', 'Negatif', 'Negatif']
# Kelas prediksi: ['Positif', 'Positif', 'Positif', 'Negatif', 'Positif', 'Negatif']
# Akurasi : 0.8333333333333334
#
# K-Fold ke 3
# Training data finish
# Kelas asli : ['Positif', 'Positif', 'Positif', 'Negatif', 'Negatif', 'Negatif']
# Kelas prediksi: ['Positif', 'Positif', 'Negatif', 'Negatif', 'Negatif', 'Negatif']
# Akurasi : 0.8333333333333334
#
# K-Fold ke 4
# Training data finish
# Kelas asli : ['Positif', 'Positif', 'Positif', 'Negatif', 'Negatif', 'Negatif']
# Kelas prediksi: ['Positif', 'Positif', 'Positif', 'Negatif', 'Negatif', 'Negatif']
# Akurasi : 1.0
#
# K-Fold ke 5
# Training data finish
# Kelas asli : ['Positif', 'Positif', 'Positif', 'Negatif', 'Negatif', 'Negatif']
# Kelas prediksi: ['Positif', 'Positif', 'Positif', 'Negatif', 'Positif', 'Negatif']
# Akurasi : 0.8333333333333334
#
# Nilai rata-rata akurasi 0.8666666666666666

# %% [markdown]
# # Data Latih

# %%
[full_term[j] for j in range(len(full_term)) if j not in k_fold[4]]

# %% [markdown]
# # Data Uji

# %%
[full_term[i] for i in k_fold[4]]
